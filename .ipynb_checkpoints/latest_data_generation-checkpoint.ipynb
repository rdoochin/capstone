# %%
from IPython.core.debugger import set_trace

import pandas as pd
import numpy as np
import os
import random
import matplotlib.pyplot as plt
import pickle
import time

# %matplotlib inline

# %% [markdown]
# In the cell below we install faker, the program we used to generate and experiment with phony test data

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-6.6.1-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 3.6 MB/s eta 0:00:01     |█████████████▊                  | 501 kB 3.6 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.4 in /opt/conda/lib/python3.8/site-packages (from faker) (2.8.1)
# Collecting text-unidecode==1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      |█████████████████████████████▍  | 71 kB 7.2 MB/s eta 0:00:01     |████████████████████████████████| 78 kB 4.3 MB/s
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.4->faker) (1.15.0)
# Installing collected packages: text-unidecode, faker
# Successfully installed faker-6.6.1 text-unidecode-1.3

# %%
from faker import Faker
from random import randint
randint(100, 999)

fake = Faker()

def faker_categorical(num=1, seed=None):
    """
    """
    np.random.seed(seed)
    fake.seed_instance(seed)

    output = [
        {
            "Student ID": randint(100000000, 999999999),
            "Name": fake.last_name(),
            "Email": fake.free_email(),
            "Phone Number": randint(1000000000, 9999999999),
                        "Gender": np.random.choice(["M", "F", "Not Specified"], p=[0.3, 0.6, 0.1]),
            "Year": np.random.choice(["Freshman", "Sophmore", "Junior", "Senior", "Graduate"]),
#             "Greek": np.random.choice([np.nan, "AEPhi", "AEPi", "ZBT", "Pi Phi", "Chi O", "Theta", "Phi Mu", "Kappa",
#                                       "Zeta Psi", "KSig", "SigEp"]),
            "Greek": np.random.choice(["AEPhi", "AEPi", "ZBT", "Pi Phi", "Chi O", "Theta", "Phi Mu", "Kappa",
                                      "Zeta Psi", "KSig", "SigEp"]),
            "Dorm": np.random.choice(["Sharp 1", "Sharp 2", "Irby 345", "Phelps 233", "Mayer 420", "Butler 5",
                                     "Sharp 4", "Monroe 2", "Irby 385", "Aron 233", "Mayer 400", "Aron 439"]),
            "In Person Class": np.random.choice(["Math", "Finance", "Science"], p=[0.4, 0.5, 0.1]),
#             "In Person Class": np.random.choice(["Math", "Finance", np.nan], p=[0.3, 0.6, 0.1]),
            "Clubs": np.random.choice(["Book club", "Cycling", "Tennis Club", "Soccer Club", "Rowing",
                                        "Karate", "Baseball Club", "Comedy Club", "Feminism", "Dance Team",
                                      "Running", "Walking", "Cookies and Code"])
#             "Clubs": np.random.choice([np.nan, "Book club", "Cycling", "Tennis Club", "Soccer Club", "Rowing",
#                                         "Karate", "Baseball Club", "Comedy Club", "Feminism", "Dance Team",
#                                       "Running", "Walking", "Cookies and Code"])
#             "avg_rating": np.random.choice(
#                 np.arange(0, 6, 1), p=[0.5, 0.05, 0.05, 0.30, 0.05, 0.05]
#             ),
        }
        for x in range(num)
    ]
    return output

# %%
df = pd.DataFrame(faker_categorical(num=100, seed=0))
df
# Out:
#     Student ID      Name                       Email  Phone Number Gender  \
# 0    597207143   Richard         gwilliams@yahoo.com    2548678896      F
# 1    149918139  Sullivan           tammy59@gmail.com    6642596922      F
# 2    155494304    Wagner          donald19@yahoo.com    9122851027      M
# 3    793105892    Archer       kyleblair@hotmail.com    4298457029      F
# 4    318594825    Rivera     gomezleslie@hotmail.com    6286828114      F
# ..         ...       ...                         ...           ...    ...
# 95   190140485    Lucero      stonekristen@gmail.com    3576994327      F
# 96   129320654   Johnson          wwallace@gmail.com    2417927322      F
# 97   706976360    Gibson       huberrachel@gmail.com    5294037486      M
# 98   861088950    Tucker  duffyelizabeth@hotmail.com    7414894217      F
# 99   376371564       Liu    claytonweiss@hotmail.com    4927062606      M
#
#         Year     Greek        Dorm In Person Class             Clubs
# 0   Freshman    Pi Phi    Aron 439         Finance        Dance Team
# 1     Junior     Chi O    Monroe 2         Finance          Feminism
# 2   Sophmore    Phi Mu    Monroe 2         Finance          Feminism
# 3   Sophmore  Zeta Psi    Aron 233         Finance         Book club
# 4   Freshman       ZBT  Phelps 233         Finance       Soccer Club
# ..       ...       ...         ...             ...               ...
# 95  Freshman    Pi Phi    Butler 5         Finance           Running
# 96  Freshman      AEPi    Irby 345         Finance           Cycling
# 97    Senior     AEPhi   Mayer 420            Math           Cycling
# 98  Freshman       ZBT  Phelps 233            Math        Dance Team
# 99    Senior     Chi O    Aron 233            Math  Cookies and Code
#
# [100 rows x 10 columns]

# %%
# Function that returns a list of organizations which the student is involved in. 
def generate_student_org_list(student_id):
    return df.loc[df['Student ID'] == student_id]

# %%
# Testing out adding a student to the dataframe with their student ID. 
# This can be used when adding a club/organization roster to the data frame. 

df = df.append({"Student ID":653254103, "Clubs":"baking"}, ignore_index=True)
generate_student_org_list(653254103)
# Out:
#      Student ID Name Email  Phone Number Gender Year Greek Dorm  \
# 100   653254103  NaN   NaN           NaN    NaN  NaN   NaN  NaN
#
#     In Person Class   Clubs
# 100             NaN  baking

# %%
def get_student_orgs(student_id):
    student_df = df.loc[df['Student ID'] == student_id]
    student_org_list = []
  
    # List of student's orgs.
    for row in student_df.itertuples():
        for element in range(1, len(row)):
            if(str(row[element]) != "nan"):
                student_org_list.append(row[element])
    return set(student_org_list)

def get_other_students(student_id):
    for i in get_student_orgs(student_id):
        print (i)
#     # Dataframe with student's info.
#     student_df = df.loc[df['Student ID'] == student_id]
  
#     # List of other students in org.
#     for column in student_df:
#         print(column)
#         if student_df[str(column)] != "nan":
#             print('test')

# %%
get_other_students(653254103)
# Out:
# baking
# 653254103

# %%
df.loc[df.Greek == 'Chi O']
# Out:
#     Student ID       Name                         Email  Phone Number  \
# 1    149918139   Sullivan             tammy59@gmail.com  6.642597e+09
# 6    674310948      Brown         davismary@hotmail.com  3.569994e+09
# 8    913316805    Sanchez            jane13@hotmail.com  4.622187e+09
# 18   936026240     Keller       christopher91@yahoo.com  4.888803e+09
# 24   894036615    Johnson           leetara@hotmail.com  9.761770e+09
# 27   105258163     Walker         michael20@hotmail.com  4.602862e+09
# 33   626525072     Golden           deborah64@gmail.com  3.236208e+09
# 39   956804937       Page          sjohnson@hotmail.com  2.698506e+09
# 46   374822001      Baird         leecharlene@gmail.com  5.719341e+09
# 50   740111603       Roth             darin24@gmail.com  4.884637e+09
# 60   627204488  Rodriguez              zwells@yahoo.com  2.148752e+09
# 63   824321605      Drake  joneschristopher@hotmail.com  4.650011e+09
# 64   527035229     Walker            zsmith@hotmail.com  1.512258e+09
# 65   896150157      Stone             ymora@hotmail.com  6.393718e+09
# 67   975809209   Richards          ryanhoward@gmail.com  3.477907e+09
# 68   523586796      Short      leachshannon@hotmail.com  4.993130e+09
# 77   199942427      Roman        marshzachary@gmail.com  2.173140e+09
# 99   376371564        Liu      claytonweiss@hotmail.com  4.927063e+09
#
#            Gender      Year  Greek        Dorm In Person Class  \
# 1               F    Junior  Chi O    Monroe 2         Finance
# 6   Not Specified    Junior  Chi O    Monroe 2            Math
# 8               M  Freshman  Chi O     Sharp 2         Science
# 18              F    Senior  Chi O     Sharp 2         Finance
# 24  Not Specified  Freshman  Chi O  Phelps 233         Finance
# 27              F  Freshman  Chi O    Aron 439         Finance
# 33              M    Senior  Chi O    Butler 5         Finance
# 39              M  Graduate  Chi O     Sharp 1         Science
# 46              M  Freshman  Chi O  Phelps 233         Science
# 50              F    Junior  Chi O     Sharp 4            Math
# 60              F  Sophmore  Chi O     Sharp 2            Math
# 63              M  Sophmore  Chi O    Butler 5         Finance
# 64  Not Specified  Graduate  Chi O     Sharp 1         Science
# 65              F    Senior  Chi O     Sharp 4         Finance
# 67              F  Graduate  Chi O   Mayer 400            Math
# 68              F    Junior  Chi O  Phelps 233         Finance
# 77              F    Junior  Chi O    Aron 233            Math
# 99              M    Senior  Chi O    Aron 233            Math
#
#                Clubs
# 1           Feminism
# 6            Walking
# 8         Dance Team
# 18        Dance Team
# 24  Cookies and Code
# 27     Baseball Club
# 33       Soccer Club
# 39       Comedy Club
# 46          Feminism
# 50       Soccer Club
# 60       Comedy Club
# 63           Running
# 64           Running
# 65           Walking
# 67         Book club
# 68       Soccer Club
# 77            Rowing
# 99  Cookies and Code

# %%
# Creating a new dataframe that contains students who have tested positive.
positive_df = pd.DataFrame(columns={'Student ID':[],'Antibodies':[],'Date of Positive Test':[],'Name':[],
                                    'Email':[], 'Greek':[],'Gender':[], 'Year':[], 'Dorm':[], 'Clubs':[]})

def if_tested_positive(student_name):
    # Getting the index of the student in the original dataframe. 
    positive_index = df.loc[df.Name == student_name].index
    
    # Adding the student to the positive dataframe.
    positive_df = positive_df.append(df.iloc[positive_index], ignore_index=True)

# %%
# Create a new function to automatically add roommates to your contact list.

# %% [markdown]
# <b>Resources</b>
# <br>
# Installing Faker: https://www.youtube.com/watch?v=jtOtFPIiflA
# <br>

# %%
df
# Out:
#      Student ID      Name                       Email  Phone Number Gender  \
# 0     597207143   Richard         gwilliams@yahoo.com  2.548679e+09      F
# 1     149918139  Sullivan           tammy59@gmail.com  6.642597e+09      F
# 2     155494304    Wagner          donald19@yahoo.com  9.122851e+09      M
# 3     793105892    Archer       kyleblair@hotmail.com  4.298457e+09      F
# 4     318594825    Rivera     gomezleslie@hotmail.com  6.286828e+09      F
# ..          ...       ...                         ...           ...    ...
# 96    129320654   Johnson          wwallace@gmail.com  2.417927e+09      F
# 97    706976360    Gibson       huberrachel@gmail.com  5.294037e+09      M
# 98    861088950    Tucker  duffyelizabeth@hotmail.com  7.414894e+09      F
# 99    376371564       Liu    claytonweiss@hotmail.com  4.927063e+09      M
# 100   653254103       NaN                         NaN           NaN    NaN
#
#          Year     Greek        Dorm In Person Class             Clubs
# 0    Freshman    Pi Phi    Aron 439         Finance        Dance Team
# 1      Junior     Chi O    Monroe 2         Finance          Feminism
# 2    Sophmore    Phi Mu    Monroe 2         Finance          Feminism
# 3    Sophmore  Zeta Psi    Aron 233         Finance         Book club
# 4    Freshman       ZBT  Phelps 233         Finance       Soccer Club
# ..        ...       ...         ...             ...               ...
# 96   Freshman      AEPi    Irby 345         Finance           Cycling
# 97     Senior     AEPhi   Mayer 420            Math           Cycling
# 98   Freshman       ZBT  Phelps 233            Math        Dance Team
# 99     Senior     Chi O    Aron 233            Math  Cookies and Code
# 100       NaN       NaN         NaN             NaN            baking
#
# [101 rows x 10 columns]

# %%
fakeResults = []
import random
for i in range (0,101):
    n = random.randint(0,1)
    fakeResults.append(n)
fakeResults
df["Test_Result"] = fakeResults

# %%
df = df[0:99]
df
# Out:
#     Student ID      Name                       Email  Phone Number Gender  \
# 0    597207143   Richard         gwilliams@yahoo.com  2.548679e+09      F
# 1    149918139  Sullivan           tammy59@gmail.com  6.642597e+09      F
# 2    155494304    Wagner          donald19@yahoo.com  9.122851e+09      M
# 3    793105892    Archer       kyleblair@hotmail.com  4.298457e+09      F
# 4    318594825    Rivera     gomezleslie@hotmail.com  6.286828e+09      F
# ..         ...       ...                         ...           ...    ...
# 94   317087691    Mullen          vlloyd@hotmail.com  8.717403e+09      F
# 95   190140485    Lucero      stonekristen@gmail.com  3.576994e+09      F
# 96   129320654   Johnson          wwallace@gmail.com  2.417927e+09      F
# 97   706976360    Gibson       huberrachel@gmail.com  5.294037e+09      M
# 98   861088950    Tucker  duffyelizabeth@hotmail.com  7.414894e+09      F
#
#         Year     Greek        Dorm In Person Class        Clubs  Test_Result
# 0   Freshman    Pi Phi    Aron 439         Finance   Dance Team            0
# 1     Junior     Chi O    Monroe 2         Finance     Feminism            0
# 2   Sophmore    Phi Mu    Monroe 2         Finance     Feminism            0
# 3   Sophmore  Zeta Psi    Aron 233         Finance    Book club            1
# 4   Freshman       ZBT  Phelps 233         Finance  Soccer Club            0
# ..       ...       ...         ...             ...          ...          ...
# 94    Senior       ZBT    Butler 5            Math      Cycling            1
# 95  Freshman    Pi Phi    Butler 5         Finance      Running            1
# 96  Freshman      AEPi    Irby 345         Finance      Cycling            0
# 97    Senior     AEPhi   Mayer 420            Math      Cycling            1
# 98  Freshman       ZBT  Phelps 233            Math   Dance Team            0
#
# [99 rows x 11 columns]

# %%
positive_students = df[df["Test_Result"] == 1]
display(positive_students)
# Out:
#     Student ID       Name                           Email  Phone Number  \
# 3    793105892     Archer           kyleblair@hotmail.com  4.298457e+09
# 5    142630320     Durham                hramos@yahoo.com  7.100765e+09
# 7    818076351    Summers          salazarmaria@yahoo.com  7.729688e+09
# 8    913316805    Sanchez              jane13@hotmail.com  4.622187e+09
# 12   225360404      Payne                sean96@yahoo.com  5.853103e+09
# 14   341121361     Zavala              thomas12@gmail.com  7.245182e+09
# 21   377779853    Cabrera          loganmelissa@gmail.com  2.710182e+09
# 22   967139830   Williams      johnsoncynthia@hotmail.com  2.020468e+09
# 23   775974863      Greer         myersmitchell@gmail.com  1.398727e+09
# 24   894036615    Johnson             leetara@hotmail.com  9.761770e+09
# 25   222748890   Martinez        jessicabrown@hotmail.com  3.775024e+09
# 26   354041094    Johnson               qoliver@gmail.com  6.745249e+09
# 27   105258163     Walker           michael20@hotmail.com  4.602862e+09
# 28   744636271   Mcdonald            lyonspeter@yahoo.com  8.448242e+09
# 30   525192719      Wolfe          tammybrown@hotmail.com  4.090427e+09
# 31   265633858      Moore         matthewking@hotmail.com  7.496514e+09
# 32   713796461      Morse  alexandermaldonado@hotmail.com  1.739387e+09
# 35   481598371   Williams            dennis75@hotmail.com  2.745366e+09
# 36   267172577    Roberts          brittany92@hotmail.com  4.814188e+09
# 39   956804937       Page            sjohnson@hotmail.com  2.698506e+09
# 40   744234912     Barnes         martincaleb@hotmail.com  8.480968e+09
# 44   252531440     Monroe      valeriemorales@hotmail.com  8.121882e+09
# 45   423044222     Butler         lewisjennifer@gmail.com  4.836348e+09
# 50   740111603       Roth               darin24@gmail.com  4.884637e+09
# 52   183164150       Mays         mathissusan@hotmail.com  9.357628e+09
# 53   150141672       Rios             xbowman@hotmail.com  3.395773e+09
# 56   278505238       Chan       williamsfrank@hotmail.com  4.811650e+09
# 57   594593220    Roberts                 ihays@yahoo.com  1.082696e+09
# 59   300090835   Chandler             richard54@yahoo.com  4.221315e+09
# 63   824321605      Drake    joneschristopher@hotmail.com  4.650011e+09
# 64   527035229     Walker              zsmith@hotmail.com  1.512258e+09
# 67   975809209   Richards            ryanhoward@gmail.com  3.477907e+09
# 68   523586796      Short        leachshannon@hotmail.com  4.993130e+09
# 69   103992479     Harris            nsanders@hotmail.com  6.231112e+09
# 70   704239750   Williams           cindygarcia@yahoo.com  8.624197e+09
# 72   749738610  Hernandez             blittle@hotmail.com  1.751719e+09
# 73   382146578    Simpson            martha73@hotmail.com  2.654154e+09
# 74   288730657      Lynch        alecthornton@hotmail.com  5.050240e+09
# 75   101005173      Nolan            austin24@hotmail.com  5.796213e+09
# 78   380515181      Jones            billysmith@yahoo.com  2.973968e+09
# 80   626717459    Schmitt              gsantana@gmail.com  3.139985e+09
# 83   443982029     Lawson        melissayates@hotmail.com  5.133455e+09
# 84   757639312    Mcclure           kevinhudson@yahoo.com  2.822034e+09
# 85   169550675      Jones              sherri46@yahoo.com  4.753684e+09
# 87   516432845   Mitchell               brian07@yahoo.com  5.107637e+09
# 88   262336599     Thomas           nunezedward@yahoo.com  6.084431e+09
# 89   608454474    Jenkins               dhughes@gmail.com  5.910276e+09
# 94   317087691     Mullen              vlloyd@hotmail.com  8.717403e+09
# 95   190140485     Lucero          stonekristen@gmail.com  3.576994e+09
# 97   706976360     Gibson           huberrachel@gmail.com  5.294037e+09
#
#            Gender      Year     Greek        Dorm In Person Class  \
# 3               F  Sophmore  Zeta Psi    Aron 233         Finance
# 5               F    Senior     Kappa     Sharp 1         Finance
# 7               F  Graduate       ZBT     Sharp 1            Math
# 8               M  Freshman     Chi O     Sharp 2         Science
# 12              M  Graduate    Pi Phi   Mayer 420         Finance
# 14              F  Freshman      AEPi    Irby 345         Finance
# 21              F    Senior  Zeta Psi    Irby 385            Math
# 22              F    Senior       ZBT    Aron 439         Science
# 23              F  Freshman     SigEp    Irby 345         Finance
# 24  Not Specified  Freshman     Chi O  Phelps 233         Finance
# 25              F  Sophmore  Zeta Psi     Sharp 1         Finance
# 26  Not Specified  Freshman      KSig     Sharp 4         Finance
# 27              F  Freshman     Chi O    Aron 439         Finance
# 28              F  Freshman  Zeta Psi    Aron 233         Finance
# 30              F    Senior     SigEp     Sharp 4         Science
# 31              F  Freshman  Zeta Psi   Mayer 420         Finance
# 32              F  Graduate  Zeta Psi    Irby 345         Finance
# 35              M    Senior      KSig   Mayer 400            Math
# 36              F  Sophmore       ZBT    Irby 345         Finance
# 39              M  Graduate     Chi O     Sharp 1         Science
# 40              F    Junior      AEPi     Sharp 2            Math
# 44              F    Junior     AEPhi    Aron 439         Finance
# 45              F    Junior     AEPhi     Sharp 4         Finance
# 50              F    Junior     Chi O     Sharp 4            Math
# 52              M    Junior     SigEp   Mayer 420            Math
# 53              F  Sophmore       ZBT    Butler 5            Math
# 56              M  Sophmore      KSig     Sharp 4         Science
# 57              F  Freshman  Zeta Psi     Sharp 4            Math
# 59              F    Junior     Kappa    Irby 385         Finance
# 63              M  Sophmore     Chi O    Butler 5         Finance
# 64  Not Specified  Graduate     Chi O     Sharp 1         Science
# 67              F  Graduate     Chi O   Mayer 400            Math
# 68              F    Junior     Chi O  Phelps 233         Finance
# 69              F  Freshman      AEPi   Mayer 420         Finance
# 70              F  Sophmore     Theta    Butler 5         Finance
# 72              F    Senior     AEPhi    Butler 5         Finance
# 73              M  Graduate  Zeta Psi    Aron 439            Math
# 74  Not Specified  Sophmore     SigEp  Phelps 233            Math
# 75              F    Junior     AEPhi  Phelps 233            Math
# 78              M  Graduate      AEPi    Irby 345            Math
# 80              F    Junior     SigEp  Phelps 233            Math
# 83              F  Sophmore       ZBT    Irby 345         Finance
# 84              M  Graduate       ZBT    Irby 345         Finance
# 85              M    Junior  Zeta Psi  Phelps 233         Finance
# 87              M    Senior     Theta    Aron 439            Math
# 88              M  Graduate    Pi Phi     Sharp 4         Finance
# 89              F    Senior     Theta    Aron 233            Math
# 94              F    Senior       ZBT    Butler 5            Math
# 95              F  Freshman    Pi Phi    Butler 5         Finance
# 97              M    Senior     AEPhi   Mayer 420            Math
#
#                Clubs  Test_Result
# 3          Book club            1
# 5         Dance Team            1
# 7             Karate            1
# 8         Dance Team            1
# 12            Rowing            1
# 14         Book club            1
# 21          Feminism            1
# 22          Feminism            1
# 23       Soccer Club            1
# 24  Cookies and Code            1
# 25            Karate            1
# 26       Soccer Club            1
# 27     Baseball Club            1
# 28     Baseball Club            1
# 30            Karate            1
# 31           Walking            1
# 32        Dance Team            1
# 35       Comedy Club            1
# 36            Karate            1
# 39       Comedy Club            1
# 40            Rowing            1
# 44           Walking            1
# 45           Running            1
# 50       Soccer Club            1
# 52           Walking            1
# 53            Karate            1
# 56          Feminism            1
# 57        Dance Team            1
# 59  Cookies and Code            1
# 63           Running            1
# 64           Running            1
# 67         Book club            1
# 68       Soccer Club            1
# 69          Feminism            1
# 70          Feminism            1
# 72        Dance Team            1
# 73          Feminism            1
# 74       Comedy Club            1
# 75  Cookies and Code            1
# 78       Comedy Club            1
# 80         Book club            1
# 83            Karate            1
# 84         Book club            1
# 85         Book club            1
# 87     Baseball Club            1
# 88  Cookies and Code            1
# 89            Karate            1
# 94           Cycling            1
# 95           Running            1
# 97           Cycling            1

# %%
year_positives = positive_students.groupby("Year").Test_Result.value_counts()
greek_positives = positive_students.groupby("Greek").Test_Result.value_counts()

fig, (ax1,ax2) = plt.subplots(1,2, figsize=(20,4))

year_positives.plot(kind='bar', legend=False, title="By Grade", ax=ax1)
greek_positives.plot(kind='bar', legend=False, title="By Greek", ax=ax2)
# Out:
# <AxesSubplot:title={'center':'By Greek'}, xlabel='Greek,Test_Result'>

# %%
year_positives = positive_students.groupby("Year").Test_Result.value_counts()
greek_positives = positive_students.groupby("Greek").Test_Result.value_counts()

fig, (ax1,ax2) = plt.subplots(1,2, figsize=(20,4))

year_positives.plot(kind='pie', legend=False, title="By Grade", ax=ax1)
greek_positives.plot(kind='pie', legend=False, title="By Greek", ax=ax2)
# Out:
# <AxesSubplot:title={'center':'By Greek'}, ylabel='Test_Result'>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction import DictVectorizer

from sklearn.impute import KNNImputer

features = ["Year", "Greek", "Clubs"]
X_train_dict = df[features].to_dict(orient="records")

x_new_dict = [{
    "Year": "Freshman",
    "Greek" : "ZBT",
    "Clubs" : "Walking"
}]

y_train = df["Test_Result"]

# Dummy encoding
vec = DictVectorizer(sparse=False)
vec.fit(X_train_dict)
X_train = vec.transform(X_train_dict)
X_new = vec.transform(x_new_dict)

# Standardization
scaler = StandardScaler()
scaler.fit(X_train)
X_train_sc = scaler.transform(X_train)
X_new_sc = scaler.transform(X_new)

# K-Nearest Neighbors Model
model = KNeighborsRegressor(n_neighbors=30)
model.fit(X_train_sc, y_train)
model.predict(X_new_sc)
# Out:
# array([0.5])

# %%
import seaborn as sns

counts = pd.crosstab(positive_students.Greek, positive_students.Dorm)
joint = counts / counts.sum().sum()
sns.heatmap(joint) #in this instance, outbreak in ZBT irby- CT can act accordingly
# Out:
# <AxesSubplot:xlabel='Dorm', ylabel='Greek'>

# %%
greek_class_counts = positive_students.pivot_table(
    index="Year", columns="Greek",
    values="Name",  # We can pretty much count any column, as long as there are no NaNs.
    aggfunc="count" # The count function will count the number of non-null values.
)
greek_class_counts


#greek_given_class =
# Out:
# Greek     AEPhi  AEPi  Chi O  KSig  Kappa  Pi Phi  SigEp  Theta  ZBT  Zeta Psi
# Year
# Freshman    NaN   2.0    3.0   1.0    NaN     1.0    1.0    NaN  NaN       3.0
# Graduate    NaN   1.0    3.0   NaN    NaN     2.0    NaN    NaN  2.0       2.0
# Junior      3.0   1.0    2.0   NaN    1.0     NaN    2.0    NaN  NaN       1.0
# Senior      2.0   NaN    NaN   1.0    1.0     NaN    1.0    2.0  2.0       1.0
# Sophmore    NaN   NaN    1.0   1.0    NaN     NaN    1.0    1.0  3.0       2.0
